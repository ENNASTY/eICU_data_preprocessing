# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('data/apachePatientResult.csv')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3676 entries, 0 to 3675
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   apachepatientresultsid         3676 non-null   int64
#  1   patientunitstayid              3676 non-null   int64
#  2   physicianspeciality            3676 non-null   object
#  3   physicianinterventioncategory  3676 non-null   object
#  4   acutephysiologyscore           3676 non-null   int64
#  5   apachescore                    3676 non-null   int64
#  6   apacheversion                  3676 non-null   object
#  7   predictedicumortality          3676 non-null   float64
#  8   actualicumortality             3676 non-null   object
#  9   predictediculos                3676 non-null   float64
#  10  actualiculos                   3676 non-null   float64
#  11  predictedhospitalmortality     3676 non-null   float64
# ...

# %%
# supprimer les colonnes inutiles
df= df.drop(['apachepatientresultsid','patientunitstayid','preopmi','preopcardiaccath','ptcawithin24h','actualventdays','predventdays','unabridgedactualventdays'],axis=1)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3676 entries, 0 to 3675
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   physicianspeciality            3676 non-null   object
#  1   physicianinterventioncategory  3676 non-null   object
#  2   acutephysiologyscore           3676 non-null   int64
#  3   apachescore                    3676 non-null   int64
#  4   apacheversion                  3676 non-null   object
#  5   predictedicumortality          3676 non-null   float64
#  6   actualicumortality             3676 non-null   object
#  7   predictediculos                3676 non-null   float64
#  8   actualiculos                   3676 non-null   float64
#  9   predictedhospitalmortality     3676 non-null   float64
#  10  actualhospitalmortality        3676 non-null   object
#  11  predictedhospitallos           3676 non-null   float64
# ...

# %%
# diviser les données en train et test

X = df.drop('predictedicumortality',axis=1)
y = df['predictedicumortality']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
